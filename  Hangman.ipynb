# %%
import random

stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

lives=6
end_game=False
display=[]
Words=['christian','aljezera','psychology']
chosen_word=random.choice(Words)
for _ in range(len(choice_word)):
    display+='_'

while not end_game:
    guess=input('kindly input your letters: ')
    for position in range(len(chose_word)):
        letter=chosen_word[position]
        if guess==letter:
            display[position]=letter
            
    for numb in range(lives):
        if guess not in chosen_words:
            lives-=1
            if lives==0:
                end_game==True
                print('you loose')
            
    print(f"{' '.join[display]}")
    
    if '_' not in display:
        end_game=True
        print('You win')
        
    print(stage[lives])
